# %%
import pandas as pd

apt = pd.read_excel('C:/Users/user/Desktop/데이터들/아파트_2호선_전체(2022-2026).xlsx')
op = pd.read_excel('C:/Users/user/Desktop/데이터들/오피스텔_2호선_전체(2022-2026).xlsx')
dan = pd.read_excel('C:/Users/user/Desktop/데이터들/단독다가구_2호선_전체(2022-2026).xlsx')
yun = pd.read_excel('C:/Users/user/Desktop/데이터들/연립다세대_2호선_전체(2022-2026).xlsx')

# %%
apt.columns
# Out:
# Index(['NO', '역명', '시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일',
#        '거래금액(만원)', '동', '층', '매수자', '매도자', '건축년도', '도로명', '해제사유발생일', '거래유형',
#        '중개사소재지', '등기일자', '주택유형'],
#       dtype='str')

# %%
apt.size
# Out:
# 1080266

# %%
op.columns
# Out:
# Index(['NO', '역명', '시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일',
#        '거래금액(만원)', '층', '매수자', '매도자', '건축년도', '도로명', '해제사유발생일', '거래유형',
#        '중개사소재지'],
#       dtype='str')

# %%
op.size
# Out:
# 325337

# %%
dan.columns
# Out:
# Index(['NO', '역명', '시군구', '번지', '주택유형', '도로조건', '연면적(㎡)', '대지면적(㎡)', '계약년월',
#        '계약일', '거래금액(만원)', '매수자', '매도자', '건축년도', '도로명', '해제사유발생일', '거래유형',
#        '중개사소재지'],
#       dtype='str')

# %%
dan.size
# Out:
# 63198

# %%
yun.columns
# Out:
# Index(['NO', '역명', '시군구', '번지', '본번', '부번', '건물명', '전용면적(㎡)', '대지권면적(㎡)',
#        '계약년월', '계약일', '거래금액(만원)', '층', '매수자', '매도자', '건축년도', '도로명', '해제사유발생일',
#        '거래유형', '중개사소재지', '등기일자', '주택유형'],
#       dtype='str')

# %%
yun.size
# Out:
# 730290
